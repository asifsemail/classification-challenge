# %% [markdown]
# # Spam Detector

# %%
# Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
df = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %%
# Exploration Steps
display(df.describe())
print("----------")
display(df.dtypes)
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4601.000000        4601.000000    4601.000000   4601.000000
# mean         0.104553           0.213015       0.280656      0.065425
# std          0.305358           1.290575       0.504143      1.395151
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4601.000000     4601.000000       4601.000000         4601.000000
# mean        0.312223        0.095901          0.114208            0.105295
# std         0.672513        0.273824          0.391441            0.401071
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# #### Prediction: Random Forest Classifier model will perform better than Logistic Regression Model
# **Reason:**: The dataset has many features, and some of the features seem to be redundant or have complex relationships (word freq, char freq etc.). Logistic Regression performs well when the data has simple linear relationships between the feature and the target variable. Random Forest model should perform better in this situation.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
y = df["spam"]
X = df.drop(columns="spam")
display(y.head())
display(X.head())
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: spam, dtype: int64
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
# ...

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
display(y.value_counts())
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler().fit(X_train)

# %%
# Fit the Standard Scaler with the training data
X_train_scaled = scaler.transform(X_train)

# display the scaled data
display(X_train_scaled[:1])
# Out:
# array([[-0.33933373, -0.16214839, -0.55144324, -0.0455687 , -0.45260014,
#         -0.3517885 ,  3.0756918 , -0.25647335, -0.31841516, -0.37271758,
#         -0.29501265, -0.62180957, -0.32657781, -0.17617526, -0.18908381,
#          1.09187591, -0.31666446, -0.34504726, -0.93039862, -0.154063  ,
#         -0.66157193, -0.11522182, -0.28644389, -0.20366572, -0.32352185,
#         -0.30020799, -0.22881004, -0.23108839, -0.17233002, -0.22127159,
#         -0.17260004, -0.1416128 , -0.1921702 , -0.14436226, -0.19157879,
#         -0.24075252, -0.33092557, -0.05564806, -0.17725653, -0.18198114,
#         -0.12101748, -0.17228913, -0.20224232, -0.12847784, -0.29799633,
#         -0.2104819 , -0.07057583, -0.11540959, -0.15779434, -0.48712282,
#         -0.17291703,  1.90383911, -0.31944577, -0.12204215, -0.11649103,
#         -0.21175305, -0.41909144]])

# %%
# Scale the testing data
X_test_scaled = scaler.transform(X_test)

# display the scaled data
display(X_test_scaled[:1])
# Out:
# array([[-0.33933373, -0.16214839, -0.55144324, -0.0455687 , -0.45260014,
#         -0.3517885 , -0.29726709, -0.25647335, -0.31841516, -0.37271758,
#         -0.29501265, -0.62180957, -0.32657781, -0.17617526, -0.18908381,
#         -0.29202679, -0.31666446, -0.34504726, -0.93039862, -0.154063  ,
#         -0.66157193, -0.11522182, -0.28644389, -0.20366572, -0.32352185,
#         -0.30020799, -0.22881004, -0.23108839, -0.17233002, -0.22127159,
#         -0.17260004, -0.1416128 , -0.1921702 , -0.14436226, -0.19157879,
#         -0.24075252, -0.33092557, -0.05564806, -0.17725653, -0.18198114,
#         -0.12101748, -0.17228913, -0.20224232, -0.12847784, -0.29799633,
#         -0.2104819 , -0.07057583, -0.11540959, -0.15779434, -0.48712282,
#         -0.17291703, -0.30668088, -0.31944577, -0.12204215, -0.12843428,
#         -0.2444289 , -0.48382584]])

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Declare a logistic regression model.
lr_model = LogisticRegression(random_state=1)

# Fit and save the logistic regression model using the training data
# as this is a regression model, it will require the scaled data - X_train_scaled
lr_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
lr_testing_predictions = lr_model.predict(X_test_scaled)

# Review the predictions
lr_testing_predictions
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
lr_test_accuracy = accuracy_score(y_test, lr_testing_predictions)
lr_test_accuracy
# Out:
# 0.9226759339704604

# %%
# compare the accuracy between train and test data
print('Train Accuracy: %.3f' % lr_model.score(X_train_scaled, y_train))
print('Test Accuracy: %.3f' % lr_model.score(X_test_scaled, y_test))
# Out:
# Train Accuracy: 0.926
# Test Accuracy: 0.923

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
rf_model = RandomForestClassifier(random_state=1)

# Fit the model to the training data
# as this is a decision tree model, it does not require scaled data
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
rf_testing_predictions = rf_model.predict(X_test)

# Review the predictions
rf_testing_predictions
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
rf_test_accuracy = accuracy_score(y_test, rf_testing_predictions)
rf_test_accuracy
# Out:
# 0.9574283231972198

# %%
# Validate the model by checking the model accuracy between train and test data
print('Train Accuracy: %.3f' % rf_model.score(X_train, y_train))
print('Test Accuracy: %.3f' % rf_model.score(X_test, y_test))
# Out:
# Train Accuracy: 0.999
# Test Accuracy: 0.957

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# #### I'll pick Random Forest Model for the following reasons:
# - In comparision it has higher accuracy score in both training and testing data
# - Looking at training accuracy, there is a chance of overfitting, but that can be resolved by hyper parameter optimization (max_depth = 11 was tested and gave good results)
# - Dataset has multiple features with potential redundant features with complex relationships between feature and target label, which is better suited for Random Forest Model over Logistic Regression Model
